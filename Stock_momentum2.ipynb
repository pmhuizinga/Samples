# %% [markdown]
# ### Opdracht
#
# Bepaal de X beste Y maand returns en rebalance de portefeuille naar deze X.
# Rebalance vervolgens na Z maanden de portefeuille.
# Gewichten initieel gelijk (kan later nog naar market cap)
# Initieel geen transactiekosten.
#
# Dus eerste Y maanden geen actie (immers: nog geen Y maand returns)
#
# Bepaal geoptimaliseerde X en Y en Z rekening houdend met kosten factor A.
# Dus: welke stocks hebben de afgelopen periode het best gepresteerd? Deze kopen. Na X periode herzien.

# %%
# Libraries
import pandas as pd
import numpy as np

# %%
# Variables
nr_of_stocks = 5 # Number of best performing stocks
nr_of_cumulative_periods = 6 # Number of periods to calculate cumulative returns
rebalance_frequency = 3 # Number of periods to rebalancing
transaction_costs = 0.01 # 1%

# %%
file = 'stock_momentum.xlsx'
sheet = 'marketcaps'
df = pd.read_excel(file, sheet)
df_cum = df.copy(deep=True)
df_weight = df.copy(deep=True)
rows, cols = df.shape

# replace market values in df with monthly returns and append cumulative returns to df_cum dataframe.
for x in df.columns.tolist()[1:]:
    #df_weight[x] = df[x].cumsum(df).fillna(0)
    df[x] = df[x].pct_change().fillna(0) # monthly returns
    df_cum[x] = df_cum[x].pct_change(periods=nr_of_cumulative_periods).fillna(0) # cumulative returns

# sort descending on cumulative returns replace top 'nr_of_stocks' with avg weight and the remainder with zeros.
avg_weights = np.where(np.argsort(-df_cum.iloc[:,1:-1]) > nr_of_stocks, 0, 1/nr_of_stocks)

# %%
df_cum
# Out:
#           date   Stock 1   Stock 2   Stock 3   Stock 4   Stock 5   Stock 6  \
# 0   2000-01-01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   2000-02-01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   2000-03-01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   2000-04-01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   2000-05-01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5   2000-06-01  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   2000-07-01 -0.479417 -0.047565  0.024947  0.114179  0.100268 -0.144573
# 7   2000-08-01 -0.536770 -0.073077  0.278429  0.469247  0.151443 -0.188218
# 8   2000-09-01 -0.553513  0.025068  0.106539  0.339607  0.132252 -0.042951
# 9   2000-10-01 -0.471838  0.358215  0.035477  0.096042  0.059539 -0.064702
# 10  2000-11-01 -0.363935  0.358215  0.067176  0.486586 -0.040076 -0.304734
# 11  2000-12-01 -0.185526  0.045705  0.406161  0.315563 -0.191643 -0.209926
# 12  2001-01-01 -0.175944 -0.156406  0.351017  0.315563 -0.219201 -0.255073
# 13  2001-02-01 -0.223033 -0.195103  0.048203 -0.035254 -0.019663 -0.054823
# 14  2001-03-01  0.146027 -0.195103 -0.114625  0.006241 -0.219054 -0.037945
# 15  2001-04-01 -0.007565 -0.316597 -0.184066  0.241030 -0.226710  0.040362
# 16  2001-05-01 -0.096175 -0.257809 -0.192144  0.251547 -0.314252  0.151829
# 17  2001-06-01 -0.251116 -0.078660 -0.134440  0.326640 -0.048525  0.013609
# 18  2001-07-01 -0.224992 -0.049868 -0.125608  0.207123  0.152964 -0.037583
# 19  2001-08-01 -0.138881 -0.269129 -0.222763  0.138537  0.142761 -0.110988
# 20  2001-09-01 -0.372404 -0.253579 -0.133425  0.115062  0.179232 -0.181173
# 21  2001-10-01 -0.118378 -0.236992 -0.225614 -0.085850  0.155881  0.003724
# 22  2001-11-01 -0.083804 -0.252101 -0.248846 -0.285581  0.364923 -0.071826
# 193  0.223682 -0.276682 -0.176851 -0.198046 -0.140207
# 194  0.168561 -0.141060 -0.012221 -0.317635  0.004489
# 195  0.473981 -0.289153 -0.192598 -0.427508 -0.160360
# 196  0.500781 -0.289153 -0.192598 -0.208406 -0.141657
# 197  0.320131 -0.269035 -0.174248 -0.198511 -0.140397
# 198  0.389612 -0.285461 -0.183526 -0.006850 -0.148370
#
# [199 rows x 12 columns]

# %%
# # open file, sheet marketcaps
# file = 'stock_momentum.xlsx'
# sheet = 'marketcaps'
# df = pd.read_excel(file, sheet)
# periods, stocks = df.shape

# cols = df.columns.tolist()
# cols = cols[1:]
# ind = df.iloc[:,0] # first column

# df_dayreturns = pd.DataFrame(index=ind, columns=cols)

# for period in range(1, periods):
#     for stock in range(1, stocks):
#         if df.iloc[period,stock] != df.iloc[period-1,stock]:
#             df_dayreturns.iloc[period,stock-1] = (df.iloc[period,stock]/df.iloc[period-1,stock]-1)

# df_dayreturns.head()

# %%
# # calculate rolling cumulative returns.
# df_cumulative_returns = pd.DataFrame(index=ind, columns=cols)
# cum_result = 0
# # blank record for first period
# # for period in range(0, nr_of_cumulative_periods):
# #     for stock in range(1, stocks):
# #         df_cumulative_returns.iloc[period,stock-1] = 0

# for period in range(nr_of_cumulative_periods, periods):
#     for stock in range(1, stocks):
#         for period2 in range(nr_of_cumulative_periods):
#             cum_result = (1 + cum_result) * (1 + df_dayreturns.iloc[period-period2,stock-1]) - 1
#             df_cumulative_returns.iloc[period,stock-1] = cum_result
#         cum_result = 0

# df_cumulative_returns.head(20)

# %%
# # even bot alle na's op nul zetten...
# for x in df_dayreturns.columns.tolist():
#         df_dayreturns[x]=df_dayreturns[x].fillna(0)
        
# df_dayreturns.head()

# %%
def total_result(nr_of_stocks=4, rebalancing_frequency=3, nr_of_periods=6):
    return(1)

def main():
    total_result() 

if __name__ == '__main__':
    main()
    
print(total_result(1,2,3))
# Out:
# 1

# %%
# # herkennen beeindigde series. zodra > 1 nulwaarde in kolom
# df_dayreturns = df_dayreturns[df_dayreturns['Stock 7'] != 0]

# print(df_dayreturns)

# %%
# null values handling
# for period in range(3, periods):
#     for stock in range(1, stocks):
#         if df_price.iloc[period,stock] == df_price.iloc[period  -1,stock] and df_price.iloc[period,stock] == df_price.iloc[period -2,stock] :
#             df_price.iloc[period,stock] = 0

# df_price.head(10)

# %%
# import separate sheets
# wb = open_workbook('stock_momentum.xlsx')

# for sheet in wb.sheets():
#     if sheet.name = 'returns':
        
#     number_of_rows = sheet.nrows
#     number_of_columns = sheet.ncols
#     print(number_of_rows, number_of_columns)


# columnnames=[]
# for x in range(1,nr_of_stocks+1): columnnames.append(x)
#df_maxvalues = pd.DataFrame(index=ind,columns=columnnames)


#np.argsort(df)
#df.argsort()
# # make dataframe with max values
# for x in range(nr_of_cumulative_periods, rows):
#      for y in range(nr_of_stocks):
#         print(df_cum.iloc[x,1:-1].sort_values(ascending=False)[:nr_of_stocks])

# cols = df.columns.tolist()[1:]
# ind = df.iloc[:,0] # first column

#df_weight.head(10)
# pd.DataFrame(data=avg_weights[1:,1:],    # values
#               index=avg_weights[1:,0],    # 1st column as index
#               columns=avg_weights[0,1:])
